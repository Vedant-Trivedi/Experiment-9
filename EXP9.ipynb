# %% [markdown]
# <a href="https://colab.research.google.com/github/Vedant-Trivedi/Experiment-9/blob/main/EXP9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Study Of NumPy
# ##Vedant Trivedi
# ##25070123121

# %%
import numpy as np

a = np.array ([1,10,20,30,40,50,500.5])
b = np.array([[1,2,3],[4,5,6]])
print(a)
print(b)
print(a.ndim)
print(b.ndim)
print(a.shape)
print(b.shape)
print(a.dtype)
print(b.dtype)
# Out:
# [  1.   10.   20.   30.   40.   50.  500.5]
# [[1 2 3]
#  [4 5 6]]
# 1
# 2
# (7,)
# (2, 3)
# float64
# int64

# %%
np.zeros((2,3))
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
np.ones((3,3))
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.],
#        [1., 1., 1.]])

# %%
np.eye((3))
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
np.arange(1,11,2)
# Out:
# array([1, 3, 5, 7, 9])

# %%
import numpy as np
np.linspace(0,1,4)
# Out:
# array([0.        , 0.33333333, 0.66666667, 1.        ])

# %%
a = np.array ([1,10,20,30,40,50,500.5])
b = np.array([[1,2,3],[4,5,6]])
print(b*2)
print(a + 5)
# Out:
# [[ 2  4  6]
#  [ 8 10 12]]
# [  6.   15.   25.   35.   45.   55.  505.5]

# %%
print(np.mean(a))
print(np.median(a))
print(np.sum(a))
# Out:
# 93.07142857142857
# 30.0
# 651.5

# %%
np.max(a)
# Out:
# np.float64(500.5)
